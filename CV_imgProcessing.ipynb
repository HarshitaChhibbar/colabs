# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
# checking version
print(cv2.__version__)
# Out:
# 3.4.3

# %%
# image reading
img=cv2.imread('harshita.jpg',1)

# %%
print(img)
# Out:
# [[[14 12 31]
#   [16 14 33]
#   [13 11 31]
#   ...
#   [ 3  2 28]
#   [14 13 39]
#   [16 17 43]]
#
#  [[19 17 37]
#   [15 13 33]
#   [ 2  0 20]
#   ...
#   [14 13 39]
#   [14 13 39]
#   [ 8  9 35]]
#
#  [[15 13 35]
#   [11  9 31]
#   [ 0  0 18]
#   ...
#   [26 25 51]
#   [18 17 43]
#   [ 6  7 33]]
#
#  ...
#
#  [[13 19 38]
#   [13 18 39]
#   [20 24 48]
#   ...
#   [ 5  3 15]
#   [ 4  3 13]
#   [ 0  1  5]]
#
#  [[ 0  1 22]
#   [ 1  5 29]
#   [11 15 39]
#   ...
#   [ 5  3 15]
#   [ 5  4 14]
#   [ 0  0  6]]
#
#  [[ 8  9 37]
#   [ 1  2 30]
#   [ 5  6 34]
#   ...
#   [ 4  4 16]
#   [ 4  5 15]
#   [ 3  3  9]]]

# %%
img.shape
# Out:
# (225, 225, 3)

# %%
# type
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
# to display image
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F103338FD30>
